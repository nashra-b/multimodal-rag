# %%
# notebooks/03_retrieval_eval.ipynb
from ragas import evaluate
from ragas.metrics import (
    faithfulness,
    answer_relevancy,
    context_precision,
    context_recall
)

# Build a small eval set manually — 10-15 Q&A pairs from your sample PDF
eval_dataset = Dataset.from_dict({
    "question": ["What was the net income in Q3?", ...],
    "answer":   [rag_chain.invoke(q) for q in questions],
    "contexts": [retrieved_docs_for_each_q],
    "ground_truth": ["$2.3 billion", ...]
})

result = evaluate(eval_dataset, metrics=[
    faithfulness,
    answer_relevancy,
    context_precision,
    context_recall
])
print(result)   # Show scores in README
